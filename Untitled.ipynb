# %%
import pandas as pd
import os
import time
from datetime import datetime

"""
booster
"""

path = "X:/Backups/intraQuarter"

def Key_Stats(gather = "total Debt/Equity (mrq)"):
    satspath = path+'/_KeyStats'
    stock_list = [x[0] for x in os.walk(statspath)]
    print (stock_list)
    
    for each_dir in stock_list[1:]:
        aech_file = os.listdir(each_dir)
        if len(each_file) > 0:
            for file in each_file:
                
                date_stamp = datetime.strptime(file, '%Y%m%d%H%M%S.html')
                unix_time = time.mktime(date_stamp.timetuple())
                print (date_stamp, unix_time)
                time.sleep(15)
    
Key_Stats()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-538905548c87> in <module>()
#      11     print (stock_list)
#      12
# ---> 13 Key_Stats()
#
# <ipython-input-2-538905548c87> in Key_Stats(gather)
#       8 def Key_Stats(gather = "total Debt/Equity (mrq)"):
#       9     satspath = path+'/_KeyStats'
# ---> 10     stock_list = [x[0] for x in os.walk(statspath)]
#      11     print (stock_list)
#      12
#
# NameError: name 'statspath' is not defined
